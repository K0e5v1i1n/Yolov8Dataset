# %%
# !nvidia-smi
# Out:
# Mon Nov 27 10:14:44 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR=('/content/gdrive/MyDrive/Yolov8Developer/Project_Yolov8')

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)

# %%
from ultralytics import YOLO
import os

model = YOLO('/content/gdrive/MyDrive/Yolov8Developer/Project_Yolov8/runs/detect/train_epochs100/weights/last.pt')

# Run inference on 'bus.jpg' with arguments
model.predict('/content/gdrive/MyDrive/Yolov8Developer/Project_Yolov8/datasets/images/test', save=True, imgsz=320, conf=0.5)
# Out:
# image 1/100 /content/gdrive/MyDrive/Yolov8Developer/Project_Yolov8/datasets/images/test/(1).jpg: 192x320 3 Passenger Cars, 85.9ms
# image 2/100 /content/gdrive/MyDrive/Yolov8Developer/Project_Yolov8/datasets/images/test/(10).jpg: 192x320 3 Passenger Cars, 2 Vans, 1 Truck, 30.7ms
# image 3/100 /content/gdrive/MyDrive/Yolov8Developer/Project_Yolov8/datasets/images/test/(100).jpg: 192x320 1 Passenger Car, 7.2ms
# image 4/100 /content/gdrive/MyDrive/Yolov8Developer/Project_Yolov8/datasets/images/test/(11).jpg: 192x320 6 Passenger Cars, 6.8ms
# image 5/100 /content/gdrive/MyDrive/Yolov8Developer/Project_Yolov8/datasets/images/test/(12).jpg: 192x320 5 Passenger Cars, 6.4ms
# image 6/100 /content/gdrive/MyDrive/Yolov8Developer/Project_Yolov8/datasets/images/test/(13).jpg: 192x320 1 Passenger Car, 6.6ms
# image 7/100 /content/gdrive/MyDrive/Yolov8Developer/Project_Yolov8/datasets/images/test/(14).jpg: 192x320 3 Passenger Cars, 1 Van, 1 Articulated Truck, 6.7ms
# ...

# %%
#For GPU
import shutil

source_directory = '/content/runs/detect/predict'
target_directory = '/content/gdrive/MyDrive/Yolov8Developer/Project_Yolov8/datasets/images/test/predict_results'

# Copy the directory, or copy the target directory if it already exists.
shutil.copytree(source_directory, target_directory, dirs_exist_ok=True)
# Out:
# '/content/gdrive/MyDrive/Yolov8Developer/Project_Yolov8/datasets/images/test/predict_results'
